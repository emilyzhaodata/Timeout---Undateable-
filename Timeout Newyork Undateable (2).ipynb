# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://www.timeout.com/newyork/blog/meet-the-undateables-lindsey-and-guy-092617')

# %%
text = BeautifulSoup(response.text, 'html.parser')

# %%
print(text.prettify())
# Out:
# <!DOCTYPE html>
# <html class="nojs " lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Meet The Undateables: Lindsey and Guy
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script type="text/javascript">
# ...

# %%
locationTags = text.find_all('span',{'class':"s1"})
locationTags
# Out:
# [<span class="s1">Lindsey: </span>,
#  <span class="s1">“He looked like a pretty typical twentysomething guy. Nothing really stood out. He was just like any guy you’d meet at a bar. He was a little awkward.”<br/></span>,
#  <span class="s1">Guy: </span>,
#  <span class="s1">“Once she sat down, I recognized that I’d be punching above my weight for the rest of the night. She was really pretty. The conversation was easy right from the start.”</span>,
#  <span class="s1">He had a great sense of humor. But he kept saying he only wanted to ask the important questions. He wouldn’t answer any questions like ‘What do you do?’ ”<br/></span>,
#  <span class="s1">Guy: </span>,
#  <span class="s1">“Definitely more of a friend vibe. It was more like we were exploring the menu together; we were both taking notes on the food and reviewing it as we went.”</span>,
# ...

# %%
title=text.find_all('title')
title
# Out:
# [<title>Meet The Undateables: Lindsey and Guy</title>,
#  <title>icon-search</title>,
#  <title>icon-chevron-right</title>,
#  <title>icon-chevron-right</title>,
#  <title>icon-chevron-right</title>,
#  <title>icon-chevron-right</title>,
#  <title>icon-chevron-right</title>]
