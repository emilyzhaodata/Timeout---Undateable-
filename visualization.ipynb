# %%
import pandas as pd
# %matplotlib inline

# %%
date = pd.read_csv('Dating Model.csv')

# %%
date.shape
# Out:
# (12, 4)

# %%
import re

# %%
date.dtypes
# Out:
# Name                object
#  Rating            float64
# Wage Difference      int64
# Distance             int64
# dtype: object

# %%
date.groupby(' Rating')['Wage Difference'].sum().plot()

# %%
date.groupby(' Rating')['Wage Difference','Distance'].sum().plot()
